# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib
#I use TkAgg as this helps speed up plotting tremendously on Mac OS. You may want to change to GTKAgg on a Windows OS. 
#matplotlib.use('TkAgg')
#matplotlib.use('GTKAgg') 
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.pyplot import specgram
from PIL import Image

# %%
# My version of calculating a spectrogram

def calcSpecgram(data, binSize, sRate, outputType, fileName, **kwarg):
    """My user-defined spectrogram function"""
    nBins = np.int_(np.floor(len(data)/binSize))
    # Create a 2D array where each row corresponds to a time bin in data
    specArray = 1. * np.arange(nBins*binSize, dtype = complex).reshape(nBins, binSize)
    # For each row/bin, FFT to obtain the spectrum for that bin
    for i in range(nBins):
        specArray[i] = np.fft.fft(data[i*binSize:(i+1)*binSize])
    # Now decide how to present the data based on outputType
    # Raw data:
    if outputType == 'data':
        return specArray
    # Image of spectrogram
    elif outputType == 'image':
        # Manipulate the data so that it can be plotted in the desired format
        # Normalize
        specArray = specArray * 1. / np.max(np.abs(specArray))
        # Transpose to put time on x-axis
        specArray = np.transpose(np.abs(specArray))
        # Take the 1/8th root so the color scheme shows low values also
        specArray = np.power(specArray, 1/8.)
        # Take only half the spectrum since the negative frequencies are redundant
        specArray = specArray[0:np.int_(binSize/2)]
        # Reverse the spectral domain so the zero frequency is at the bottom of the plot
        specArray = specArray[::-1]
        # Plot
        f = plt.figure()
        sp = f.add_subplot(111)
        sp.imshow(specArray, interpolation='nearest', cmap="viridis", aspect='auto')
        # If the markers are inserted in the **kwarg position, then plot them too
        if ('markers' in kwarg):
            sp.plot(np.asarray(kwarg['markers'][0])/binSize, binSize/2/2 + np.zeros(len(kwarg['markers'][0])), 'y1')
            sp.plot(np.asarray(kwarg['markers'][1])/binSize, binSize/2/2 + np.zeros(len(kwarg['markers'][1])), 'w1')
        sp.set_xlabel('Time in sec')
        sp.set_ylabel('Frequency (arb)')
        # Specify the ticks and their labels: 1 every second, and 10 frequency ticks
        xTickList = np.arange(0, nBins, np.int(1.0*sRate/binSize))
        xLabelList = np.int_(np.round(np.arange(0, nBins, np.int(1.0*sRate/binSize))*binSize/sRate/1.0))
        yTickList = np.arange(np.int_(binSize/2), 0, -1*np.int_(np.int_(binSize/2)/10))
        yLabelList = (  np.int_((binSize/2)*(sRate/2)/(np.int_(binSize/2))) - 
                        np.int_(np.arange(np.int_(binSize/2), 0, -1*np.int_(np.int_(binSize/2)/10))*
                        (sRate/2)/(np.int_(binSize/2)))  )
        sp.set_xticks(xTickList)
        sp.set_xticklabels(xLabelList)
        sp.set_yticks(yTickList)
        sp.set_yticklabels(yLabelList)
        plt.title(fileName)
        plt.close()
        return f
    else:
        print('Bad outputType. Choose \'data\' or \'image\'')

# %%
# Class approach to define heartbeat objects

class heartbeat:
    """A class to define a heartbeat object to pull values from"""
    
    # Upon initialization, import data, sampling rate, duration
    def __init__(self, fileName):
        self.fileName = fileName
        self.pandaDF = pd.read_csv(fileName, delimiter=',')
        self.data = self.pandaDF.values
        self.data = np.reshape(self.data,len(self.data))
        self.sRate = int(self.pandaDF.columns[0])
        self.duration = self.data.size / self.sRate
    
    # Simple plotting function for the data
    def plot(self):
        f = plt.figure()
        sp = f.add_subplot(111)
        sp.plot(self.data,'k-')
        sp.axis([0,len(self.data),min(self.data)*1.1,max(self.data)*1.1])
        sp.set_xlabel('Sample number')
        sp.set_ylabel('Signal amplitude')
        plt.title(self.fileName)
        plt.close()
        return f
    
    # Spectrogram plotting function using matplotlib's specgram function
    def spectrogram(self):
        f = plt.figure()
        sp = f.add_subplot(111)
        specgram(self.data,Fs=self.sRate) # Apparently this plots the spectrogram in the subplot
        sp.set_xlabel('Time in sec')
        sp.set_ylabel('Frequency')
        plt.title(self.fileName)
        plt.close()
        return f

    # Specgtrogram calculation function that can return a plot or data, using my definition above
    def spectrogram2(self, binSize, outputType):
        f = calcSpecgram(self.data, binSize, self.sRate, outputType, self.fileName)
        return f
    
    # Function to determine if data set has markers, the number of markers, and their data indices
    def markers(self):
        if self.fileName[:4] == 'SetA': # Only SetA has timing markers
            # Import the data from the timing marker file
            markerPDF = pd.read_csv('SetA/set_a_timing.csv', delimiter=',')
            markerData = markerPDF.values
            # Establish variables to store the number of markers and their indices in the file
            nMarkers = 0
            indices = []
            # Loop through the rows in the timing file to find matching the fileName
            for i in range(np.int_(markerData.size/4)):
                if markerData[i, 0] == 'set_a/' + self.fileName[5:-4] + '.wav':
                    nMarkers = nMarkers + 1
                    indices.append(i)
            # If the fileName was found at least once, return the desired output
            if nMarkers > 0:
                return [True, nMarkers, indices]
            else: # The fileName was not located inside the timing marker file
                return [False, 0, []]
        else: # If the fileName didn't belong to SetA
            return [False, 0, []]
        
    # Function to grab the S1 and S2 locations in the data set
    def lubdubs(self):
        # Determine if there are even timing markers for this data set
        if self.markers()[0]:
            # Import the timing marker data
            markerPDF = pd.read_csv('SetA/set_a_timing.csv', delimiter=',')
            markerData = markerPDF.values
            # Establish an array to be filled with the timing marker locations
            output = [[], []]
            for i in self.markers()[2]:
                # There are only 'S1' and 'S2' markers
                if markerData[i, 2] == 'S1':
                    output[0].append(markerData[i, 3])
                else: # a.k.a. 'S2'
                    output[1].append(markerData[i, 3])
            return output
        else: # If there weren't timing markers for the data set, return an empty array
            return [[], []]
    
    # Advanced plotting function with markers indicated
    def plotWM(self):
        # Grab the locations of 'S1' and 'S2'
        markers = self.lubdubs()
        # Start the simple plot routine
        f = plt.figure()
        sp = f.add_subplot(111)
        sp.plot(self.data,'k-')
        # Now add the markers to the plot
        sp.plot(markers[0], max(self.data)*1.07 + np.zeros(len(markers[0])), 'r1', label = 'S1')
        sp.plot(markers[1], max(self.data)*1.07 + np.zeros(len(markers[1])), 'b1', label = 'S2')
        # Now continue with the formatting
        sp.axis([0,len(self.data),min(self.data)*1.1,max(self.data)*1.1])
        sp.set_xlabel('Sample number')
        sp.set_ylabel('Signal amplitude')
        plt.title(self.fileName)
        plt.close()
        return f
    
    # Advanced spectrogram plotting function using matplotlib's specgram function, with markers
    def spectrogramWM(self):
        # Grab the locations of 'S1' and 'S2'
        markers = self.lubdubs()
        # Start the simple spectrogram plot routine
        f = plt.figure()
        sp = f.add_subplot(111)
        specgram(self.data,Fs=self.sRate, zorder=1) # Apparently this plots the spectrogram in the subplot
        # Now add the markers to the plot
        sp.plot(np.asarray(markers[0])/self.sRate, 0.5*self.sRate/2 + np.zeros(len(markers[0])), 'y1')
        sp.plot(np.asarray(markers[1])/self.sRate, 0.5*self.sRate/2 + np.zeros(len(markers[1])), 'w1')
        # Now continue with the formatting
        sp.set_xlabel('Time in sec')
        sp.set_ylabel('Frequency')
        plt.title(self.fileName)
        plt.close()
        return f
    
    # Advanced specgtrogram calculation function using my definition above, with markers
    def spectrogram2WM(self, binSize, outputType):
        f = calcSpecgram(self.data, binSize, self.sRate, outputType, self.fileName, markers = self.lubdubs())
        return f

# %%
# Define a heartbeat object based on a normal heartbeat sound file
hb1 = heartbeat('SetA/normal__201108011118.csv')

# %%
# Plot the waveform with markers
hb1.plotWM()

# %%
# Plot the spectrogram using the matplotlib specgram function
hb1.spectrogramWM()

# %%
# Plot the spectrogram using the user defined function, with 40 msec bin size
timeBin = 0.005
sampleBinSize = int(hb1.sRate*timeBin)
hb1.spectrogram2WM(sampleBinSize,'image')
